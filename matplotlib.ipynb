# %%
pip install matplotlib
# Out:
# ...
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace(0,10,200)

# %%
x
# Out:
# array([ 0.        ,  0.05025126,  0.10050251,  0.15075377,  0.20100503,
#         0.25125628,  0.30150754,  0.35175879,  0.40201005,  0.45226131,
#         0.50251256,  0.55276382,  0.60301508,  0.65326633,  0.70351759,
#         0.75376884,  0.8040201 ,  0.85427136,  0.90452261,  0.95477387,
#         1.00502513,  1.05527638,  1.10552764,  1.15577889,  1.20603015,
#         1.25628141,  1.30653266,  1.35678392,  1.40703518,  1.45728643,
#         1.50753769,  1.55778894,  1.6080402 ,  1.65829146,  1.70854271,
#         1.75879397,  1.80904523,  1.85929648,  1.90954774,  1.95979899,
#         2.01005025,  2.06030151,  2.11055276,  2.16080402,  2.21105528,
#         2.26130653,  2.31155779,  2.36180905,  2.4120603 ,  2.46231156,
#         2.51256281,  2.56281407,  2.61306533,  2.66331658,  2.71356784,
#         2.7638191 ,  2.81407035,  2.86432161,  2.91457286,  2.96482412,
#         3.01507538,  3.06532663,  3.11557789,  3.16582915,  3.2160804 ,
# ...

# %%
y = np.sin(x)

# %%
y
# Out:
# array([ 0.        ,  0.05023011,  0.10033341,  0.15018339,  0.19965422,
#         0.24862099,  0.29696008,  0.34454944,  0.39126893,  0.43700061,
#         0.481629  ,  0.52504145,  0.56712835,  0.60778345,  0.6469041 ,
#         0.68439153,  0.72015112,  0.75409257,  0.78613019,  0.8161831 ,
#         0.84417544,  0.87003651,  0.89370105,  0.91510929,  0.9342072 ,
#         0.95094655,  0.96528509,  0.97718662,  0.98662108,  0.99356467,
#         0.99799984,  0.99991541,  0.99930653,  0.99617474,  0.99052796,
#         0.98238043,  0.97175273,  0.95867168,  0.94317032,  0.92528777,
#         0.90506919,  0.88256563,  0.85783388,  0.8309364 ,  0.80194109,
#         0.77092115,  0.7379549 ,  0.70312557,  0.66652108,  0.62823386,
#         0.58836056,  0.54700186,  0.50426216,  0.46024937,  0.41507461,
#         0.36885193,  0.32169803,  0.27373195,  0.22507478,  0.17584939,
#         0.12618003,  0.07619211,  0.02601183, -0.02423412, -0.07441889,
# ...

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel("This is my x data")
plt.ylabel("This is my y data")
plt.title("This is my title")
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x,y)

# %%
colours = np.random.rand(50)
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x,y, c = colours)
# now the will get the dot with the different colours

# %%
colours = np.random.rand(50)
sizes = np.random.rand(50)
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x,y, c = colours, s = sizes)
# now i will get the dot with the different colours.
# # now i will get the dot with the different sizes

# %%
colours = np.random.rand(50)
sizes =  1000*np.random.rand(50)   # the size of dot is increased to 1000 times
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x,y, c = colours, s = sizes)
# now i will get the dot with the different colours.
# # now i will get the dot with the different sizes

# %%
colours = np.random.rand(50)
sizes =  1000*np.random.rand(50)   # the size of dot is increased to 1000 times
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x,y, c = colours, s = sizes, alpha = +1)
# now i will get the dot with the different colours.
# now i will get the dot with the different sizes.
# alpha represents the intensity of the dot's color.

# %%
colours = np.random.rand(50)
sizes =  1000*np.random.rand(50)   # the size of dot is increased to 1000 times
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x,y, c = colours, s = sizes, alpha = -1)
# now i will get the dot with the different colours.
# now i will get the dot with the different sizes.
# alpha represents the intensity of the dot's color.
# The range of color using the alpha parameter mut be from 0 to 1, else error will come
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 5
#       3 x = np.random.rand(50)
#       4 y = np.random.rand(50)
# ----> 5 plt.scatter(x,y, c = colours, s = sizes, alpha = -1)
#       6 # now i will get the dot with the different colours.
#       7 # now i will get the dot with the different sizes.
#       8 # alpha represents the intensity of the dot's color.
#       9 # The range of color using the alpha parameter mut be from 0 to 1, else error will come
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
# ...

# %%
colours = np.random.rand(50)
sizes =  1000*np.random.rand(50)   # the size of dot is increased to 1000 times
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x,y, c = colours, s = sizes, alpha = .5)
# now i will get the dot with the different colours.
# now i will get the dot with the different sizes.
# alpha represents the intensity of the dot's color.
# The range of color using the alpha parameter mut be from 0 to 1, else error will come

# %%
colours = np.random.rand(50)
sizes =  1000*np.random.rand(50)   # the size of dot is increased to 1000 times
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x,y, c = colours, s = sizes, alpha = 0.31)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Random data")
# now i will get the dot with the different colours.
# now i will get the dot with the different sizes.
# alpha represents the intensity of the dot's color.
# The range of color using the alpha parameter mut be from 0 to 1, else error will come
# Out:
# Text(0.5, 1.0, 'Random data')

# %%
x = ["a", "b", "c", "d", "e"]
y = np.random.rand(5)
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
x = ["a", "b", "c", "d", "e"]
y = np.random.rand(5)
plt.bar(x,y)
# vertical bar-graph
# categorical vs numerical data.
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Bar-graph")
# Out:
# Text(0.5, 1.0, 'Bar-graph')

# %%
x = ["a", "b", "c", "d", "e"]
y = np.random.rand(5)
plt.barh(x,y)      # It will become horizontal bar-graph
# vertical bar-graph
# categorical vs numerical data.
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Bar-graph")
# Out:
# Text(0.5, 1.0, 'Bar-graph')

# %%
x = np.linspace(0,10,200)
y = np.sin(x)
plt.plot(x,y, "--r")
plt.xlabel("This is my x data")
plt.ylabel("This is my y data")
plt.title("This is my title")
plt.show()

# %%
x = np.linspace(0,10,200)
y = np.sin(x)
plt.plot(x,y, "--b")
plt.xlabel("This is my x data")
plt.ylabel("This is my y data")
plt.title("This is my title")
plt.show()

# %%
x = np.linspace(0,10,200)
y = np.sin(x)
plt.plot(x,y, "-g")
plt.xlabel("This is my x data")
plt.ylabel("This is my y data")
plt.title("This is my title")
plt.show()

# %%
x = np.linspace(0,10,200)
y = np.sin(x)
plt.plot(x,y, "r")
plt.xlabel("This is my x data")
plt.ylabel("This is my y data")
plt.title("This is my title")
plt.show()

# %%
x = np.linspace(0,10,200)
y = np.sin(x)
plt.plot(x,y, "--bl")
plt.xlabel("This is my x data")
plt.ylabel("This is my y data")
plt.title("This is my title")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 3
#       1 x = np.linspace(0,10,200)
#       2 y = np.sin(x)
# ----> 3 plt.plot(x,y, "--bl")
#       4 plt.xlabel("This is my x data")
#       5 plt.ylabel("This is my y data")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\pyplot.py:3829, in plot(scalex, scaley, data, *args, **kwargs)
#    3821 @_copy_docstring_and_deprecators(Axes.plot)
#    3822 def plot(
#    3823     *args: float | ArrayLike | str,
#    (...)
#    3827     **kwargs,
#    3828 ) -> list[Line2D]:
# -> 3829     return gca().plot(
#    3830         *args,
#    3831         scalex=scalex,
#    3832         scaley=scaley,
#    3833         **({"data": data} if data is not None else {}),
#    3834         **kwargs,
#    3835     )
#
# ...

# %%
x = np.linspace(0,10,200)
y = np.sin(x)
plt.figure(figsize=(8,4))    #This way i can control the figure size
plt.plot(x,y, "--r")
plt.xlabel("This is my x data")
plt.ylabel("This is my y data")
plt.title("This is my title")
plt.show()

# %%
x = np.linspace(0,10,200)
y = np.sin(x)
plt.figure(figsize=(8,4))    #This way i can control the figure size
plt.plot(x,y, "--r")
plt.xlabel("This is my x data")
plt.ylabel("This is my y data")
plt.title("This is my title")
plt.grid() #It will show grid
plt.show()

# %%
colours = np.random.rand(50)
sizes =  1000*np.random.rand(50)   # the size of dot is increased to 1000 times
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x,y, c = colours, s = sizes, alpha = 0.31)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Random data")
# now i will get the dot with the different colours.
# now i will get the dot with the different sizes.
# alpha represents the intensity of the dot's color.
# The range of color using the alpha parameter mut be from 0 to 1, else error will come
# Out:
# Text(0.5, 1.0, 'Random data')

# %%
colours = np.random.rand(50)
sizes =  1000*np.random.rand(50)   # the size of dot is increased to 1000 times
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x,y, c = "b", s = sizes, alpha = 0.31)  #Even i can show the colour manually
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Random data")
# now i will get the dot with the different colours.
# now i will get the dot with the different sizes.
# alpha represents the intensity of the dot's color.
# The range of color using the alpha parameter mut be from 0 to 1, else error will come
# Out:
# Text(0.5, 1.0, 'Random data')

# %%
colours = np.random.rand(50)
sizes =  1000*np.random.rand(50)   # the size of dot is increased to 1000 times
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x,y, c = "#8c52e0", s = sizes, alpha = 0.31)  # type html colour code at chrome
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Random data")
# now i will get the dot with the different colours.
# now i will get the dot with the different sizes.
# alpha represents the intensity of the dot's color.
# The range of color using the alpha parameter mut be from 0 to 1, else error will come
# Out:
# Text(0.5, 1.0, 'Random data')

# %%
colours = np.random.rand(50)
sizes =  1000*np.random.rand(50)   # the size of dot is increased to 1000 times
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x,y, c = "#8c52e0", s = sizes, alpha = 0.31, marker = "x")  # type html colour code at chrome
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Random data")
# now i will get the dot with the different colours.
# now i will get the dot with the different sizes.
# alpha represents the intensity of the dot's color.
# The range of color using the alpha parameter mut be from 0 to 1, else error will come
# Out:
# Text(0.5, 1.0, 'Random data')

# %%
colours = np.random.rand(50)
sizes =  1000*np.random.rand(50)   # the size of dot is increased to 1000 times
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x,y, c = "b", s = sizes, alpha = 0.31, marker = "")  # type html colour code at chrome
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Random data")
# now i will get the dot with the different colours.
# now i will get the dot with the different sizes.
# alpha represents the intensity of the dot's color.
# The range of color using the alpha parameter mut be from 0 to 1, else error will come
# Out:
# Text(0.5, 1.0, 'Random data')

# %%
x = [4,5,6,7,8,9]
y = [6,7,8,9,10,11]
plt.plot(x,y)

# %%
x = [4,5,6,7,8,9]
y = [6,7,8,9,10,11]
plt.plot(x,y)
plt.show()

# %%
x = [4,5,6,7,8,9]
y = [60,30,80,19,40,1]
plt.plot(x,y)
plt.show()

# %%
x = [4,5,6,7,8,9]
y = [60,30,80,19,40,1]
plt.scatter(x,y)
plt.show()

# %%
x = [4,5,6,7,8,9]
y = [60,30,80,19,40,1]
plt.bar(x,y)
plt.show()

# %%
x = [4,5,6,7,8,9]
y = [60,30,80,19,40,1]
plt.barh(x,y)
plt.show()

# %%
# Now using the histogram we will see the no. of repetition of a number
data = [1,2,3,4,5,1,2,3,6,7,8,1,2,3]
plt.hist(data)
plt.show()
# Here x-axis will show any dataset and y-axis will show its repitition.

# %%
x = [4,5,6,7,8,9]
y = [60,30,80,19,40,1]
color = ["red", "blue", "green", "#8c52e0", "#dce052", "orange"]
plt.scatter(x,y, c=color)
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)
fig = plt.figure()
ax = fig.add_subplot(projection = "3d")  #NOw, we will see the graph in 3d
ax.scatter(x,y,z)
plt.show()
